# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
tet = pd.read_csv("circle.csv")

# %%
tet["R/D"] = tet["R"]/tet["D"]
tet["error"] = abs(tet["Analytic"] - tet["Numerical"])
tet["error%"] = tet["error"]/tet["Analytic"] * 100

# %%
# plt.scatter(tet["Num Nodes"],tet["TTH Time"], marker="x",color="green")


# a, b ,c ,d = np.polyfit(tri["Num Nodes"],tri["Mesh Time"],3)

# x = np.linspace(np.min(tri["Num Nodes"]), np.max(tri["Num Nodes"]))
# y_fit = a*x**3+b*x**2+c*x+d 
# plt.plot(x,y_fit,color="red")

# a, b ,c ,d = np.polyfit(tet["Num Nodes"],tet["Mesh Time"],3)
# x = np.linspace(np.min(tet["Num Nodes"]), np.max(tet["Num Nodes"]))
# y_fit = a*x**3+b*x**2+c*x+d 

# plt.plot(x,y_fit,color="green")

plt.show()

# plt.plot(tet["R/D"],tet["Analytic"])
plt.plot(tet["R/D"],tet["Numerical"])
# plt.plot(tet["R/D"],tet["Analytic"])
plt.show()

# plt.scatter(tri["R/D"][-4:-1],tri["error%"][-4:-1])
# plt.show()

# %%
tet
# Out:
#           R         D      Analytic     Numerical       R/D         error  \
# 0  0.000010  0.000007  8.385244e-12  3.027060e-11  1.428571  2.188536e-11
# 1  0.000011  0.000007  9.362173e-12  3.181010e-11  1.610169  2.244793e-11
# 2  0.000011  0.000006  1.046409e-11  4.373390e-11  1.818182  3.326981e-11
# 3  0.000012  0.000006  1.171807e-11  4.701420e-11  2.058824  3.529613e-11
# 4  0.000012  0.000005  1.315978e-11  6.614520e-11  2.340426  5.298542e-11
# 5  0.000013  0.000005  1.483734e-11  8.359420e-11  2.674419  6.875686e-11
# 6  0.000013  0.000004  1.681726e-11  8.832360e-11  3.076923  7.150634e-11
# 7  0.000014  0.000004  1.919441e-11  1.274960e-10  3.571429  1.083016e-10
# 8  0.000014  0.000003  2.210915e-11  1.480170e-10  4.193548  1.259078e-10
# 9  0.000015  0.000003  2.577893e-11  9.673860e-10  5.000000  9.416071e-10
#
#         error%
# 0   260.998444
# 1   239.772617
# 2   317.942517
# 3   301.211151
# 4   402.631399
# 5   463.404308
# 6   425.196145
# 7   564.235062
# ...

# %% [markdown]
# Conclusion: Triangular meshes are not the way to go. Possibly investigate for thin film structures
